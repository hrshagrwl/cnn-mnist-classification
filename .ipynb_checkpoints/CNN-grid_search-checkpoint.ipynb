# %%
import tensorflow as tf
#tf.set_random_seed(7)
print ("TensorFlow version: " + tf.__version__)
import keras
# Out:
# TensorFlow version: 1.13.0-rc2
# Using TensorFlow backend.

# %%
from mlxtend.data import loadlocal_mnist
from sklearn.model_selection import train_test_split

files = {
    "X": "data/train-images-idx3-ubyte",
    "y": "data/train-labels-idx1-ubyte",
    "X_test": "data/t10k-images-idx3-ubyte",
    "y_test": "data/t10k-labels-idx1-ubyte"
}


# Code to load the binary files.
# https://github.com/rasbt/mlxtend/blob/master/mlxtend/data/local_mnist.py

X, y = loadlocal_mnist(images_path = files['X'], labels_path = files['y'])
X_test, y_test = loadlocal_mnist(images_path = files['X_test'], labels_path = files['y_test'])

# %%
X = X.reshape(X.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)


# Split the data
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=42)

print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (45000, 28, 28, 1)
# (15000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
#import talos as ta
p = {'lr': (0.01, 0.05, 0.1),
     'batch_size': (32, 64, 128),
     'dropout': (0, 0.5, 5)}

# %%
import numpy as np
np.random.seed(1337)
def one_hot_encode(data):
    encoded_data = np.zeros((data.shape[0], 10), dtype=np.float32)
    for index, digit in enumerate(data):
        encoded_data[(index, digit)] = 1
    return encoded_data

    
encoded_y_train = one_hot_encode(y_train)
encoded_y_valid = one_hot_encode(y_valid)
encoded_y_test = one_hot_encode(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout
from keras import optimizers


# create model
#def talos_model(X_train, y_train, X_valid, y_valid, params):
best_lr = 0.01
best_bs = 128
best_dr = 0.5
best_val_acc = 0
bestmodel = None
for learning_rate in p['lr']:
    for bs in p['batch_size']:
        for dr in p['dropout']:
            print('lr = {} batch_size = {} dropout = {}'.format(learning_rate, bs, dr))
            model = Sequential()
            # add model layers
            model.add(Conv2D(64, kernel_size = 3, activation = 'relu', input_shape =(28, 28, 1)))
            model.add(Conv2D(32, kernel_size = 3, activation = 'relu'))
            model.add(Flatten())
            model.add(Dense(128, activation='relu'))
            #one more dropout for convergence' sake :) 
            model.add(Dropout(dr))
            model.add(Dense(10, activation = 'softmax', kernel_initializer='random_uniform',bias_initializer='zeros'))
            sgd = optimizers.SGD(lr=learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
            model.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])
            hist = model.fit(X_train, encoded_y_train, validation_data = (X_valid,encoded_y_valid),batch_size=bs, epochs = 3)
            validation_acc = max(hist.history['val_acc'])
            print(validation_acc)
            print()
            if(validation_acc > best_val_acc):
                best_val_acc = validation_acc
                best_lr = learning_rate
                best_bs = bs
                best_dr = dr
                bestmodel = model
            
print('Best hyperpaframeters')
print('Learning rate {}'.format(best_lr))
print('Batch size {}'.format(best_bs))
print('Dropout {}'.format(best_dr))
print('Validation accuracy {}'.format(best_val_acc))
#encoded_y= one_hot_encode(y)
#t = ta.Scan(x=X,y=encoded_y,model=talos_model,val_split = 0.25,grid_downsample=0.01, params=p)#,save_best_model = True)
#model.fit(X_train, encoded_y_train, validation_data = (X_valid, encoded_y_valid),batch_size=params['batch_size'], epochs = 3)
# Out:
# lr = 0.01 batch_size = 32 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 108s 2ms/step - loss: 14.5346 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 2/3
# 45000/45000 [==============================] - 116s 3ms/step - loss: 14.5425 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 3/3
# 45000/45000 [==============================] - 113s 3ms/step - loss: 14.5425 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# 0.09620000000198682
#
# lr = 0.01 batch_size = 32 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 143s 3ms/step - loss: 14.5197 - acc: 0.0974 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 2/3
# 45000/45000 [==============================] - 135s 3ms/step - loss: 14.5432 - acc: 0.0977 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 3/3
# 45000/45000 [==============================] - 107s 2ms/step - loss: 14.5421 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# 0.09620000000198682
#
# lr = 0.01 batch_size = 32 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 100s 2ms/step - loss: 14.5051 - acc: 0.0997 - val_loss: 14.5374 - val_acc: 0.0981
# Epoch 2/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 14.5109 - acc: 0.0997 - val_loss: 14.5374 - val_acc: 0.0981
# Epoch 3/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 14.5109 - acc: 0.0997 - val_loss: 14.5374 - val_acc: 0.0981
# 0.09806666666865349
#
# lr = 0.01 batch_size = 64 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 92s 2ms/step - loss: 14.5137 - acc: 0.0986 - val_loss: 14.5117 - val_acc: 0.0997
# Epoch 2/3
# 45000/45000 [==============================] - 97s 2ms/step - loss: 14.5321 - acc: 0.0984 - val_loss: 14.5117 - val_acc: 0.0997
# Epoch 3/3
# 45000/45000 [==============================] - 96s 2ms/step - loss: 14.5321 - acc: 0.0984 - val_loss: 14.5117 - val_acc: 0.0997
# 0.0996666666686535
#
# lr = 0.01 batch_size = 64 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 93s 2ms/step - loss: 2.3288 - acc: 0.1176 - val_loss: 2.3016 - val_acc: 0.1099
# Epoch 2/3
# 45000/45000 [==============================] - 92s 2ms/step - loss: 2.3016 - acc: 0.1126 - val_loss: 2.3019 - val_acc: 0.1099
# Epoch 3/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 2.3015 - acc: 0.1132 - val_loss: 2.3018 - val_acc: 0.1099
# 0.10993333331743876
#
# lr = 0.01 batch_size = 64 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 93s 2ms/step - loss: 14.4990 - acc: 0.0996 - val_loss: 14.5374 - val_acc: 0.0981
# Epoch 2/3
# 45000/45000 [==============================] - 91s 2ms/step - loss: 14.5109 - acc: 0.0997 - val_loss: 14.5374 - val_acc: 0.0981
# Epoch 3/3
# 45000/45000 [==============================] - 92s 2ms/step - loss: 14.5109 - acc: 0.0997 - val_loss: 14.5374 - val_acc: 0.0981
# 0.09806666666865349
#
# lr = 0.01 batch_size = 128 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 95s 2ms/step - loss: 14.2739 - acc: 0.1128 - val_loss: 14.3462 - val_acc: 0.1099
# Epoch 2/3
# 45000/45000 [==============================] - 93s 2ms/step - loss: 14.2939 - acc: 0.1132 - val_loss: 14.3462 - val_acc: 0.1099
# Epoch 3/3
# 45000/45000 [==============================] - 97s 2ms/step - loss: 14.2939 - acc: 0.1132 - val_loss: 14.3462 - val_acc: 0.1099
# 0.10993333331743876
#
# lr = 0.01 batch_size = 128 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 1.0014 - acc: 0.6838 - val_loss: 0.3445 - val_acc: 0.8890
# Epoch 2/3
# 45000/45000 [==============================] - 103s 2ms/step - loss: 0.3046 - acc: 0.9082 - val_loss: 0.1419 - val_acc: 0.9549
# Epoch 3/3
# 45000/45000 [==============================] - 102s 2ms/step - loss: 0.1739 - acc: 0.9476 - val_loss: 0.1025 - val_acc: 0.9701
# 0.9700666666348775
#
# lr = 0.01 batch_size = 128 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 106s 2ms/step - loss: 14.2620 - acc: 0.1131 - val_loss: 14.3462 - val_acc: 0.1099
# Epoch 2/3
# 45000/45000 [==============================] - 101s 2ms/step - loss: 14.2939 - acc: 0.1132 - val_loss: 14.3462 - val_acc: 0.1099
# Epoch 3/3
# 45000/45000 [==============================] - 100s 2ms/step - loss: 14.2939 - acc: 0.1132 - val_loss: 14.3462 - val_acc: 0.1099
# 0.10993333331743876
#
# lr = 0.05 batch_size = 32 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 104s 2ms/step - loss: 14.5071 - acc: 0.0996 - val_loss: 14.4192 - val_acc: 0.1054
# Epoch 2/3
# 45000/45000 [==============================] - 98s 2ms/step - loss: 14.5124 - acc: 0.0996 - val_loss: 14.4192 - val_acc: 0.1054
# Epoch 3/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 14.5124 - acc: 0.0996 - val_loss: 14.4192 - val_acc: 0.1054
# 0.10540000000794729
#
# lr = 0.05 batch_size = 32 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 108s 2ms/step - loss: 14.4597 - acc: 0.1025 - val_loss: 14.4869 - val_acc: 0.1012
# Epoch 2/3
# 45000/45000 [==============================] - 115s 3ms/step - loss: 14.4658 - acc: 0.1025 - val_loss: 14.4869 - val_acc: 0.1012
# Epoch 3/3
# 45000/45000 [==============================] - 98s 2ms/step - loss: 14.4655 - acc: 0.1025 - val_loss: 14.4869 - val_acc: 0.1012
# 0.10120000000397364
#
# lr = 0.05 batch_size = 32 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 14.4533 - acc: 0.1028 - val_loss: 14.3612 - val_acc: 0.1090
# Epoch 2/3
# 45000/45000 [==============================] - 98s 2ms/step - loss: 14.4597 - acc: 0.1029 - val_loss: 14.3612 - val_acc: 0.1090
# Epoch 3/3
# 45000/45000 [==============================] - 98s 2ms/step - loss: 14.4597 - acc: 0.1029 - val_loss: 14.3612 - val_acc: 0.1090
# 0.10900000000794728
#
# lr = 0.05 batch_size = 64 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 92s 2ms/step - loss: 14.5310 - acc: 0.0977 - val_loss: 14.5654 - val_acc: 0.0963
# Epoch 2/3
# 45000/45000 [==============================] - 91s 2ms/step - loss: 14.5400 - acc: 0.0979 - val_loss: 14.5654 - val_acc: 0.0963
# Epoch 3/3
# 45000/45000 [==============================] - 91s 2ms/step - loss: 14.5400 - acc: 0.0979 - val_loss: 14.5654 - val_acc: 0.0963
# 0.09633333333333334
#
# lr = 0.05 batch_size = 64 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 102s 2ms/step - loss: 14.2749 - acc: 0.1136 - val_loss: 14.3462 - val_acc: 0.1099
# Epoch 2/3
# 45000/45000 [==============================] - 91s 2ms/step - loss: 14.2925 - acc: 0.1133 - val_loss: 14.3462 - val_acc: 0.1099
# Epoch 3/3
# 45000/45000 [==============================] - 95s 2ms/step - loss: 14.2928 - acc: 0.1132 - val_loss: 14.3462 - val_acc: 0.1099
# 0.10993333331743876
#
# lr = 0.05 batch_size = 64 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 91s 2ms/step - loss: 14.5158 - acc: 0.0986 - val_loss: 14.5256 - val_acc: 0.0988
# Epoch 2/3
# 45000/45000 [==============================] - 112s 2ms/step - loss: 14.5292 - acc: 0.0986 - val_loss: 14.5256 - val_acc: 0.0988
# Epoch 3/3
# 45000/45000 [==============================] - 113s 3ms/step - loss: 14.5292 - acc: 0.0986 - val_loss: 14.5256 - val_acc: 0.0988
# 0.09880000000397364
#
# lr = 0.05 batch_size = 128 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 136s 3ms/step - loss: 14.5180 - acc: 0.0977 - val_loss: 14.5654 - val_acc: 0.0963
# Epoch 2/3
# 45000/45000 [==============================] - 93s 2ms/step - loss: 14.5400 - acc: 0.0979 - val_loss: 14.5654 - val_acc: 0.0963
# Epoch 3/3
# 45000/45000 [==============================] - 104s 2ms/step - loss: 14.5400 - acc: 0.0979 - val_loss: 14.5654 - val_acc: 0.0963
# 0.09633333333333334
#
# lr = 0.05 batch_size = 128 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 126s 3ms/step - loss: 2.3793 - acc: 0.1106 - val_loss: 2.3018 - val_acc: 0.1099
# Epoch 2/3
# 45000/45000 [==============================] - 93s 2ms/step - loss: 2.3019 - acc: 0.1128 - val_loss: 2.3017 - val_acc: 0.1099
# Epoch 3/3
# 45000/45000 [==============================] - 94s 2ms/step - loss: 2.3021 - acc: 0.1121 - val_loss: 2.3029 - val_acc: 0.1099
# 0.10993333331743876
#
# lr = 0.05 batch_size = 128 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 95s 2ms/step - loss: 14.6465 - acc: 0.0896 - val_loss: 14.6320 - val_acc: 0.0922
# Epoch 2/3
# 45000/45000 [==============================] - 94s 2ms/step - loss: 14.6718 - acc: 0.0897 - val_loss: 14.6320 - val_acc: 0.0922
# Epoch 3/3
# 45000/45000 [==============================] - 94s 2ms/step - loss: 14.6718 - acc: 0.0897 - val_loss: 14.6320 - val_acc: 0.0922
# 0.0922
#
# lr = 0.1 batch_size = 32 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 103s 2ms/step - loss: 14.5256 - acc: 0.0983 - val_loss: 14.5117 - val_acc: 0.0997
# Epoch 2/3
# 45000/45000 [==============================] - 99s 2ms/step - loss: 14.5321 - acc: 0.0984 - val_loss: 14.5117 - val_acc: 0.0997
# Epoch 3/3
# 45000/45000 [==============================] - 102s 2ms/step - loss: 14.5321 - acc: 0.0984 - val_loss: 14.5117 - val_acc: 0.0997
# 0.0996666666686535
#
# lr = 0.1 batch_size = 32 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 100s 2ms/step - loss: 14.4173 - acc: 0.1052 - val_loss: 14.3612 - val_acc: 0.1090
# Epoch 2/3
# 45000/45000 [==============================] - 100s 2ms/step - loss: 14.4074 - acc: 0.1061 - val_loss: 14.3612 - val_acc: 0.1090
# Epoch 3/3
# 45000/45000 [==============================] - 108s 2ms/step - loss: 14.4171 - acc: 0.1055 - val_loss: 14.3612 - val_acc: 0.1090
# 0.10900000000794728
#
# lr = 0.1 batch_size = 32 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 111s 2ms/step - loss: 14.5262 - acc: 0.0983 - val_loss: 14.5117 - val_acc: 0.0997
# Epoch 2/3
# 45000/45000 [==============================] - 123s 3ms/step - loss: 14.5321 - acc: 0.0984 - val_loss: 14.5117 - val_acc: 0.0997
# Epoch 3/3
# 45000/45000 [==============================] - 103s 2ms/step - loss: 14.5321 - acc: 0.0984 - val_loss: 14.5117 - val_acc: 0.0997
# 0.0996666666686535
#
# lr = 0.1 batch_size = 64 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 124s 3ms/step - loss: 14.5070 - acc: 0.0990 - val_loss: 14.5203 - val_acc: 0.0991
# Epoch 2/3
# 45000/45000 [==============================] - 106s 2ms/step - loss: 14.5199 - acc: 0.0992 - val_loss: 14.5203 - val_acc: 0.0991
# Epoch 3/3
# 45000/45000 [==============================] - 106s 2ms/step - loss: 14.5199 - acc: 0.0992 - val_loss: 14.5203 - val_acc: 0.0991
# 0.09913333333730698
#
# lr = 0.1 batch_size = 64 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 102s 2ms/step - loss: 14.3880 - acc: 0.1067 - val_loss: 14.5289 - val_acc: 0.0986
# Epoch 2/3
# 45000/45000 [==============================] - 116s 3ms/step - loss: 14.3716 - acc: 0.1084 - val_loss: 14.5289 - val_acc: 0.0986
# Epoch 3/3
# 45000/45000 [==============================] - 94s 2ms/step - loss: 14.3992 - acc: 0.1066 - val_loss: 14.5289 - val_acc: 0.0986
# 0.0986
#
# lr = 0.1 batch_size = 64 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 3056s 68ms/step - loss: 14.5155 - acc: 0.0986 - val_loss: 14.5256 - val_acc: 0.0988
# Epoch 2/3
# 45000/45000 [==============================] - 94s 2ms/step - loss: 14.5292 - acc: 0.0986 - val_loss: 14.5256 - val_acc: 0.0988
# Epoch 3/3
# 45000/45000 [==============================] - 95s 2ms/step - loss: 14.5292 - acc: 0.0986 - val_loss: 14.5256 - val_acc: 0.0988
# 0.09880000000397364
#
# lr = 0.1 batch_size = 128 dropout = 0
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 2960s 66ms/step - loss: 14.5162 - acc: 0.0977 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 2/3
# 45000/45000 [==============================] - 94s 2ms/step - loss: 14.5425 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 3/3
# 45000/45000 [==============================] - 93s 2ms/step - loss: 14.5425 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# 0.09620000000198682
#
# lr = 0.1 batch_size = 128 dropout = 0.5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 96s 2ms/step - loss: 14.5109 - acc: 0.0983 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 2/3
# 45000/45000 [==============================] - 317s 7ms/step - loss: 14.5425 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# Epoch 3/3
# 45000/45000 [==============================] - 102s 2ms/step - loss: 14.5410 - acc: 0.0978 - val_loss: 14.5675 - val_acc: 0.0962
# 0.09620000000198682
#
# lr = 0.1 batch_size = 128 dropout = 5
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 100s 2ms/step - loss: 14.4536 - acc: 0.1016 - val_loss: 14.5009 - val_acc: 0.1003
# Epoch 2/3
# 45000/45000 [==============================] - 114s 3ms/step - loss: 14.4784 - acc: 0.1017 - val_loss: 14.5009 - val_acc: 0.1003
# Epoch 3/3
# 45000/45000 [==============================] - 110s 2ms/step - loss: 14.4784 - acc: 0.1017 - val_loss: 14.5009 - val_acc: 0.1003
# 0.10033333333532016
#
# Best hyperpaframeters
# Learning rate 0.01
# Batch size 128
# Dropout 0.5
# Validation accuracy 0.9700666666348775

# %%
from sklearn.metrics import accuracy_score

y_pred = bestmodel.predict(X_test)

# %%
y_pred[:10]
op = np.unravel_index(np.argmax(y_pred, axis=1), y_pred.shape)

# %%
accuracy_score(y_test, op[1])
# Out:
# 0.9769
